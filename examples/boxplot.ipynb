# %%
from fav_plots.box import scatter_box
import pandas as pd
import numpy as np

# Create the first dummy DataFrame
data1 = {'value': np.random.normal(50, 4, 100)}
df1 = pd.DataFrame(data1)

# Create the second dummy DataFrame
data2 = {'value': np.random.normal(60, 8, 100)}
df2 = pd.DataFrame(data2)

# %%
metric = 'value'
fig_box = scatter_box(df1, df2, metric)

# %%
fig_box.set_xticklabels(['df1','df2'])
fig_box.get_xticklabels()
# Out:
# [Text(0, 0, 'df1'), Text(1, 0, 'df2')]
